# %%
a = 13
type(a)
# Out:
# int

# %%
d = 2.5
type(d)
# Out:
# float

# %%
name = "diksha"
type(name)
# Out:
# str

# %%
e="krishna"
type(e)
# Out:
# str

# %%
is_raining = True
print('is_raining')
# Out:
# is_raining

# %%
"diksha".lower()
# Out:
# 'diksha'

# %%
"diksha".upper()
# Out:
# 'DIKSHA'

# %%
a=12
float(a)
# Out:
# 12.0

# %%
a=5
b=3
a+b
# Out:
# 8

# %%
x=5
y=7
x-y
# Out:
# -2

# %%
x=7
y=6
x*y
# Out:
# 42

# %%
x=9
y=4
print(x+y)
print(x-y)
print(x*y)
print(x/y)
print(x//y)
print(x%y)
print(x**y)
# Out:
# 13
# 5
# 36
# 2.25
# 2
# 1
# 6561

# %%
x=10
y=5
print(x>y)
print(x<y)
print(x!=y)
print(x>=y)
print(x<=y)
# Out:
# True
# False
# True
# True
# False

# %%
x=10
b=4
print(x==y)
# Out:
# False

# %%
spam="hello world!"
spam=spam.upper()
spam
# Out:
# 'HELLO WORLD!'

# %%
spam="hello world!"
spam=spam.lower()
spam
# Out:
# 'hello world!'

# %%
x=True
y=False
print(x and y)
print(x or y)
print(not x)
print(not y)
# Out:
# False
# True
# False
# True

# %%
data = "apple,banana,cherry"
Fruits=data.split(",")
print(Fruits)
# Out:
# ['apple', 'banana', 'cherry']

# %%
'hello'.isalpha()
# Out:
# True

# %%
'hello0123'.isalpha()
# Out:
# False

# %% [markdown]
# # assignment operators

# %%
a=10
a+=5
a
a-=5
a
# Out:
# 10

# %% [raw]
# result = 10 + 2 * 3
# print(result)
